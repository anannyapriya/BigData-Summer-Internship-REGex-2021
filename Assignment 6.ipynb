# %%
# /FileStore/tables/ratings.csv

# %%
from pyspark.sql import SparkSession

# %%
df = spark.read.csv("/FileStore/tables/ratings.csv", header=True)

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------+-------+------+---------+
# userid|movieId|rating|timestamp|
# +------+-------+------+---------+
#      1|      1|     4|964982703|
#      1|      3|     4|964981247|
#      1|      6|     4|964982224|
#      1|     47|     5|964983815|
#      1|     50|     5|964982931|
#      1|     70|     3|964982400|
#      1|    101|     5|964980868|
#      1|    110|     4|964982176|
#      1|    151|     5|964984041|
#      1|    157|     5|964984100|
#      1|    163|     5|964983650|
#      1|    216|     5|964981208|
#      1|    223|     3|964980985|
#      1|    231|     5|964981179|
#      1|    235|     4|964980908|
#      1|    260|     5|964981680|
#      1|    296|     3|964982967|
#      1|    316|     3|964982310|
#      1|    333|     5|964981179|
#      1|    349|     4|964982563|
# +------+-------+------+---------+
# only showing top 20 rows
#
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>['userid', 'movieId', 'rating', 'timestamp']</div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>root
# -- userid: string (nullable = true)
# -- movieId: string (nullable = true)
# -- rating: string (nullable = true)
# -- timestamp: string (nullable = true)
#
# </div>

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-------+------------------+----------------+------------------+--------------------+
# summary|            userid|         movieId|            rating|           timestamp|
# +-------+------------------+----------------+------------------+--------------------+
#   count|            100836|          100836|            100836|              100836|
#    mean|326.12756356856676|19435.2957177992| 3.501556983616962|1.2059460873684695E9|
#  stddev| 182.6184914635004|35530.9871987003|1.0425292390606342|2.1626103599513078E8|
#     min|                 1|               1|               0.5|          1000129365|
#     max|                99|           99992|                 5|           999873731|
# +-------+------------------+----------------+------------------+--------------------+
#
# </div>

# %%
#Q1. showing columns userid, movieId and timestamp column present in form of date for those movies whose rate is in between 3.0 and 5.0
df.select("userid", "movieId", "timestamp").where((df["rating"] >= 3) & (df["rating"] <= 5)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>[Row(userid='1', movieId='1', timestamp='964982703'),
#  Row(userid='1', movieId='3', timestamp='964981247'),
#  Row(userid='1', movieId='6', timestamp='964982224'),
#  Row(userid='1', movieId='47', timestamp='964983815'),
#  Row(userid='1', movieId='50', timestamp='964982931'),
#  Row(userid='1', movieId='70', timestamp='964982400'),
#  Row(userid='1', movieId='101', timestamp='964980868'),
#  Row(userid='1', movieId='110', timestamp='964982176'),
#  Row(userid='1', movieId='151', timestamp='964984041'),
#  Row(userid='1', movieId='157', timestamp='964984100'),
#  Row(userid='1', movieId='163', timestamp='964983650'),
#  Row(userid='1', movieId='216', timestamp='964981208'),
#  Row(userid='1', movieId='223', timestamp='964980985'),
#  Row(userid='1', movieId='231', timestamp='964981179'),
#  Row(userid='1', movieId='235', timestamp='964980908'),
#  Row(userid='1', movieId='260', timestamp='964981680'),
#  Row(userid='1', movieId='296', timestamp='964982967'),
#  Row(userid='1', movieId='316', timestamp='964982310'),
#  Row(userid='1', movieId='333', timestamp='964981179'),
#  Row(userid='1', movieId='349', timestamp='964982563'),
#  Row(userid='1', movieId='356', timestamp='964980962'),
#  Row(userid='1', movieId='362', timestamp='964982588'),
#  Row(userid='1', movieId='367', timestamp='964981710'),
#  Row(userid='1', movieId='423', timestamp='964982363'),
#  Row(userid='1', movieId='441', timestamp='964980868'),
#  Row(userid='1', movieId='457', timestamp='964981909'),
#  Row(userid='1', movieId='480', timestamp='964982346'),
#  Row(userid='1', movieId='500', timestamp='964981208'),
#  Row(userid='1', movieId='527', timestamp='964984002'),
#  Row(userid='1', movieId='543', timestamp='964981179'),
#  Row(userid='1', movieId='552', timestamp='964982653'),
#  Row(userid='1', movieId='553', timestamp='964984153'),
#  Row(userid='1', movieId='590', timestamp='964982546'),
#  Row(userid='1', movieId='592', timestamp='964982271'),
#  Row(userid='1', movieId='593', timestamp='964983793'),
#  Row(userid='1', movieId='596', timestamp='964982838'),
#  Row(userid='1', movieId='608', timestamp='964982931'),
#  Row(userid='1', movieId='648', timestamp='964982563'),
#  Row(userid='1', movieId='661', timestamp='964982838'),
#  Row(userid='1', movieId='673', timestamp='964981775'),
#  Row(userid='1', movieId='733', timestamp='964982400'),
#  Row(userid='1', movieId='736', timestamp='964982653'),
#  Row(userid='1', movieId='780', timestamp='964984086'),
#  Row(userid='1', movieId='804', timestamp='964980499'),
#  Row(userid='1', movieId='919', timestamp='964982475'),
#  Row(userid='1', movieId='923', timestamp='964981529'),
#  Row(userid='1', movieId='940', timestamp='964982176'),
#  Row(userid='1', movieId='943', timestamp='964983614'),
#  Row(userid='1', movieId='954', timestamp='964983219'),
#  Row(userid='1', movieId='1009', timestamp='964981775'),
#  Row(userid='1', movieId='1023', timestamp='964982681'),
#  Row(userid='1', movieId='1024', timestamp='964982876'),
#  Row(userid='1', movieId='1025', timestamp='964982791'),
#  Row(userid='1', movieId='1029', timestamp='964982855'),
#  Row(userid='1', movieId='1030', timestamp='964982903'),
#  Row(userid='1', movieId='1031', timestamp='964982653'),
#  Row(userid='1', movieId='1032', timestamp='964982791'),
#  Row(userid='1', movieId='1042', timestamp='964981179'),
#  Row(userid='1', movieId='1049', timestamp='964982400'),
#  Row(userid='1', movieId='1060', timestamp='964980924'),
#  Row(userid='1', movieId='1073', timestamp='964981680'),
#  Row(userid='1', movieId='1080', timestamp='964981327'),
#  Row(userid='1', movieId='1089', timestamp='964982951'),
#  Row(userid='1', movieId='1090', timestamp='964984018'),
#  Row(userid='1', movieId='1092', timestamp='964983484'),
#  Row(userid='1', movieId='1097', timestamp='964981680'),
#  Row(userid='1', movieId='1127', timestamp='964982513'),
#  Row(userid='1', movieId='1136', timestamp='964981327'),
#  Row(userid='1', movieId='1196', timestamp='964981827'),
#  Row(userid='1', movieId='1197', timestamp='964981872'),
#  Row(userid='1', movieId='1198', timestamp='964981827'),
#  Row(userid='1', movieId='1206', timestamp='964983737'),
#  Row(userid='1', movieId='1208', timestamp='964983250'),
#  Row(userid='1', movieId='1210', timestamp='964980499'),
#  Row(userid='1', movieId='1213', timestamp='964982951'),
#  Row(userid='1', movieId='1214', timestamp='964981855'),
#  Row(userid='1', movieId='1220', timestamp='964981909'),
#  Row(userid='1', movieId='1222', timestamp='964981909'),
#  Row(userid='1', movieId='1224', timestamp='964984018'),
#  Row(userid='1', movieId='1226', timestamp='964983618'),
#  Row(userid='1', movieId='1240', timestamp='964983723'),
#  Row(userid='1', movieId='1256', timestamp='964981442'),
#  Row(userid='1', movieId='1258', timestamp='964983414'),
#  Row(userid='1', movieId='1265', timestamp='964983599'),
#  Row(userid='1', movieId='1270', timestamp='964983705'),
#  Row(userid='1', movieId='1275', timestamp='964982290'),
#  Row(userid='1', movieId='1278', timestamp='964983414'),
#  Row(userid='1', movieId='1282', timestamp='964982703'),
#  Row(userid='1', movieId='1291', timestamp='964981909'),
#  Row(userid='1', movieId='1298', timestamp='964984086'),
#  Row(userid='1', movieId='1348', timestamp='964983393'),
#  Row(userid='1', movieId='1377', timestamp='964982653'),
#  Row(userid='1', movieId='1396', timestamp='964983017'),
#  Row(userid='1', movieId='1408', timestamp='964982310'),
#  Row(userid='1', movieId='1445', timestamp='964984112'),
#  Row(userid='1', movieId='1473', timestamp='964980875'),
#  Row(userid='1', movieId='1500', timestamp='964980985'),
#  Row(userid='1', movieId='1517', timestamp='964981107'),
#  Row(userid='1', movieId='1552', timestamp='964982620'),
#  Row(userid='1', movieId='1573', timestamp='964982290'),
#  Row(userid='1', movieId='1580', timestamp='964981125'),
#  Row(userid='1', movieId='1587', timestamp='964982346'),
#  Row(userid='1', movieId='1617', timestamp='964982951'),
#  Row(userid='1', movieId='1620', timestamp='964983056'),
#  Row(userid='1', movieId='1625', timestamp='964983504'),
#  Row(userid='1', movieId='1644', timestamp='964983536'),
#  Row(userid='1', movieId='1676', timestamp='964982620'),
#  Row(userid='1', movieId='1732', timestamp='964981125'),
#  Row(userid='1', movieId='1777', timestamp='964981230'),
#  Row(userid='1', movieId='1793', timestamp='964981404'),
#  Row(userid='1', movieId='1804', timestamp='964983034'),
#  Row(userid='1', movieId='1805', timestamp='964983056'),
#  Row(userid='1', movieId='1920', timestamp='964981780'),
#  Row(userid='1', movieId='1927', timestamp='964981497'),
#  Row(userid='1', movieId='1954', timestamp='964982176'),
#  Row(userid='1', movieId='1967', timestamp='964981710'),
#  Row(userid='1', movieId='2000', timestamp='964982211'),
#  Row(userid='1', movieId='2005', timestamp='964981710'),
#  Row(userid='1', movieId='2012', timestamp='964984176'),
#  Row(userid='1', movieId='2018', timestamp='964980523'),
#  Row(userid='1', movieId='2028', timestamp='964981888'),
#  Row(userid='1', movieId='2033', timestamp='964982903'),
#  Row(userid='1', movieId='2046', timestamp='964982563'),
#  Row(userid='1', movieId='2048', timestamp='964982791'),
#  Row(userid='1', movieId='2054', timestamp='964981747'),
#  Row(userid='1', movieId='2058', timestamp='964982400'),
#  Row(userid='1', movieId='2078', timestamp='964982838'),
#  Row(userid='1', movieId='2090', timestamp='964982838'),
#  Row(userid='1', movieId='2093', timestamp='964981710'),
#  Row(userid='1', movieId='2094', timestamp='964982653'),
#  Row(userid='1', movieId='2096', timestamp='964982838'),
#  Row(userid='1', movieId='2099', timestamp='964982588'),
#  Row(userid='1', movieId='2105', timestamp='964981725'),
#  Row(userid='1', movieId='2115', timestamp='964982529'),
#  Row(userid='1', movieId='2116', timestamp='964982876'),
#  Row(userid='1', movieId='2137', ti

# %%
#Q2. Printing movies which were made after the year 2000
from pyspark.sql import functions as func

# %%
df1 = df.withColumnRenamed("timestamp", "time").withColumn("timestamp", func.from_unixtime("time"))
df1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------+-------+------+---------+-------------------+
# userid|movieId|rating|     time|          timestamp|
# +------+-------+------+---------+-------------------+
#      1|      1|     4|964982703|2000-07-30 18:45:03|
#      1|      3|     4|964981247|2000-07-30 18:20:47|
#      1|      6|     4|964982224|2000-07-30 18:37:04|
#      1|     47|     5|964983815|2000-07-30 19:03:35|
#      1|     50|     5|964982931|2000-07-30 18:48:51|
#      1|     70|     3|964982400|2000-07-30 18:40:00|
#      1|    101|     5|964980868|2000-07-30 18:14:28|
#      1|    110|     4|964982176|2000-07-30 18:36:16|
#      1|    151|     5|964984041|2000-07-30 19:07:21|
#      1|    157|     5|964984100|2000-07-30 19:08:20|
#      1|    163|     5|964983650|2000-07-30 19:00:50|
#      1|    216|     5|964981208|2000-07-30 18:20:08|
#      1|    223|     3|964980985|2000-07-30 18:16:25|
#      1|    231|     5|964981179|2000-07-30 18:19:39|
#      1|    235|     4|964980908|2000-07-30 18:15:08|
#      1|    260|     5|964981680|2000-07-30 18:28:00|
#      1|    296|     3|964982967|2000-07-30 18:49:27|
#      1|    316|     3|964982310|2000-07-30 18:38:30|
#      1|    333|     5|964981179|2000-07-30 18:19:39|
#      1|    349|     4|964982563|2000-07-30 18:42:43|
# +------+-------+------+---------+-------------------+
# only showing top 20 rows
#
# </div>

# %%
df1.select("userid", "movieId", "timestamp").filter(df1["timestamp"] > "2000-07-30 18:45:03").collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>[Row(userid='1', movieId='47', timestamp='2000-07-30 19:03:35'),
#  Row(userid='1', movieId='50', timestamp='2000-07-30 18:48:51'),
#  Row(userid='1', movieId='151', timestamp='2000-07-30 19:07:21'),
#  Row(userid='1', movieId='157', timestamp='2000-07-30 19:08:20'),
#  Row(userid='1', movieId='163', timestamp='2000-07-30 19:00:50'),
#  Row(userid='1', movieId='296', timestamp='2000-07-30 18:49:27'),
#  Row(userid='1', movieId='527', timestamp='2000-07-30 19:06:42'),
#  Row(userid='1', movieId='553', timestamp='2000-07-30 19:09:13'),
#  Row(userid='1', movieId='593', timestamp='2000-07-30 19:03:13'),
#  Row(userid='1', movieId='596', timestamp='2000-07-30 18:47:18'),
#  Row(userid='1', movieId='608', timestamp='2000-07-30 18:48:51'),
#  Row(userid='1', movieId='661', timestamp='2000-07-30 18:47:18'),
#  Row(userid='1', movieId='780', timestamp='2000-07-30 19:08:06'),
#  Row(userid='1', movieId='943', timestamp='2000-07-30 19:00:14'),
#  Row(userid='2', movieId='68157', timestamp='2015-10-24 19:32:34'),
#  Row(userid='2', movieId='71535', timestamp='2015-10-24 19:29:34'),
#  Row(userid='2', movieId='74458', timestamp='2015-10-24 19:28:46'),
#  Row(userid='2', movieId='77455', timestamp='2015-10-24 19:29:01'),
#  Row(userid='2', movieId='79132', timestamp='2015-10-24 19:27:21'),
#  Row(userid='2', movieId='80489', timestamp='2015-10-24 19:35:40'),
#  Row(userid='2', movieId='80906', timestamp='2015-10-24 19:32:52'),
#  Row(userid='2', movieId='86345', timestamp='2015-10-24 19:32:46'),
#  Row(userid='2', movieId='89774', timestamp='2015-10-24 19:33:09'),
#  Row(userid='2', movieId='91529', timestamp='2015-10-24 19:28:11'),
#  Row(userid='2', movieId='91658', timestamp='2015-10-24 19:28:58'),
#  Row(userid='2', movieId='99114', timestamp='2015-10-24 19:27:54'),
#  Row(userid='2', movieId='106782', timestamp='2015-10-24 19:29:26'),
#  Row(userid='2', movieId='109487', timestamp='2015-10-24 19:32:25'),
#  Row(userid='2', movieId='112552', timestamp='2015-10-24 19:28:02'),
#  Row(userid='2', movieId='114060', timestamp='2015-10-24 19:34:36'),
#  Row(userid='2', movieId='115713', timestamp='2015-10-24 19:27:34'),
#  Row(userid='2', movieId='122882', timestamp='2015-10-24 19:34:32'),
#  Row(userid='2', movieId='131724', timestamp='2015-10-24 19:27:31'),
#  Row(userid='3', movieI

# %%
#Q3. Showing the dataframe of the total count of movies for each movie id that's created between the year 2000 and 2001
from pyspark.sql import SparkSession
from pyspark.sql.functions import count

df1.select(count("movieId")).groupBy("movieId")
df1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------+-------+------+---------+-------------------+
# userid|movieId|rating|     time|          timestamp|
# +------+-------+------+---------+-------------------+
#      1|      1|     4|964982703|2000-07-30 18:45:03|
#      1|      3|     4|964981247|2000-07-30 18:20:47|
#      1|      6|     4|964982224|2000-07-30 18:37:04|
#      1|     47|     5|964983815|2000-07-30 19:03:35|
#      1|     50|     5|964982931|2000-07-30 18:48:51|
#      1|     70|     3|964982400|2000-07-30 18:40:00|
#      1|    101|     5|964980868|2000-07-30 18:14:28|
#      1|    110|     4|964982176|2000-07-30 18:36:16|
#      1|    151|     5|964984041|2000-07-30 19:07:21|
#      1|    157|     5|964984100|2000-07-30 19:08:20|
#      1|    163|     5|964983650|2000-07-30 19:00:50|
#      1|    216|     5|964981208|2000-07-30 18:20:08|
#      1|    223|     3|964980985|2000-07-30 18:16:25|
#      1|    231|     5|964981179|2000-07-30 18:19:39|
#      1|    235|     4|964980908|2000-07-30 18:15:08|
#      1|    260|     5|964981680|2000-07-30 18:28:00|
#      1|    296|     3|964982967|2000-07-30 18:49:27|
#      1|    316|     3|964982310|2000-07-30 18:38:30|
#      1|    333|     5|964981179|2000-07-30 18:19:39|
#      1|    349|     4|964982563|2000-07-30 18:42:43|
# +------+-------+------+---------+-------------------+
# only showing top 20 rows
#
# </div>
